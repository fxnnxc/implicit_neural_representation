# %% [markdown]
# ## Set 5

# %%
import os 
from PIL import Image
import numpy as np 
import matplotlib.pyplot as plt

# %%
path = "background256.jpg"
img = Image.open(path)
img = np.array(img)
print(f"{path:15s} | shape:{img.shape} | max:{img.max()} | min:{img.min()}")
# Out:
# background256.jpg | shape:(256, 256, 3) | max:245 | min:0

# %%
plt.imshow(img.mean(axis=-1))
